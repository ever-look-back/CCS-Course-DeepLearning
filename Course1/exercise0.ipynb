# %%
list1 = [1,2,"Peter",4.50,"Ricky",5,6]
list2 = [1,2,5,"Peter",4.50,"Ricky",6]

# %%
list1 == list2
# Out:
# False

# %%
type(list1)
type(list2)
# Out:
# list

# %%
list1[1:3]
# Out:
# [2, 'Peter']

# %%
a = (1)
tup1 = (1,)
tup2 = (1,2)

# %%
type(a)
type(tup1)
type(tup2)
# Out:
# tuple

# %%
tup3 = tup1 + tup2
print(tup3)
# Out:
# (1, 1, 2)

# %%
# %timeit sum(range(1000))
# Out:
# 10.8 μs ± 486 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
# %pwd
# Out:
# 'E:\\Jupyter Notebooks'

# %%
# %ls
# Out:
#  驱动器 E 中的卷没有标签。
#  卷的序列号是 1C9E-4465
#
#  E:\Jupyter Notebooks 的目录
#
# 2026/05/06  15:31    <DIR>          .
# 2026/05/06  15:29    <DIR>          CCS_Course_DeepLearning
#                0 个文件              0 字节
#                2 个目录 24,254,820,352 可用字节

# %%
import ipywidgets as widgets
from IPython.display import display

slider = widgets.IntSlider(value=10, min=0, max=100, step=1)
display(slider)

# 绑定事件
def on_change(change):
    print(f"新值: {change['new']}")
slider.observe(on_change, names='value')
# Out:
# IntSlider(value=10)

# %%
from ipywidgets import interact

@interact(x=(0, 10, 0.5))
def square(x):
    return x ** 2
# Out:
# interactive(children=(FloatSlider(value=5.0, description='x', max=10.0, step=0.5), Output()), _dom_classes=('w…
